# %%
import pandas as pd
import csv

# %%
order_items_dataset=pd.read_csv('olist_order_items_dataset.csv')  # Olist items datasest
order_items_dataset.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0        9/19/17 9:45   58.90          13.29
# 1        5/3/17 11:05  239.90          19.93
# 2       1/18/18 14:48  199.00          17.87
# 3       8/15/18 10:10   12.99          12.79
# 4       2/13/17 13:57  199.90          18.14

# %%
order_dataset=pd.read_csv('olist_orders_dataset.csv')  # Olist orders datasest
order_dataset.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered            10/2/17 10:56     10/2/17 11:07
# 1    delivered            7/24/18 20:41      7/26/18 3:24
# 2    delivered              8/8/18 8:38       8/8/18 8:55
# 3    delivered           11/18/17 19:28    11/18/17 19:45
# 4    delivered            2/13/18 21:18     2/13/18 22:20
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                10/4/17 19:55                10/10/17 21:25
# 1                7/26/18 14:31                  8/7/18 15:27
# 2                 8/8/18 13:50                 8/17/18 18:06
# 3               11/22/17 13:39                  12/2/17 0:28
# 4                2/14/18 19:46                 2/16/18 18:17
#
#   order_estimated_delivery_date
# 0                 10/18/17 0:00
# 1                  8/13/18 0:00
# 2                   9/4/18 0:00
# 3                 12/15/17 0:00
# 4                  2/26/18 0:00

# %%
olist_order_order_items=pd.merge(order_dataset, order_items_dataset,on=['order_id','order_id']) #full outer join based on seller id
olist_order_order_items.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered            10/2/17 10:56     10/2/17 11:07
# 1    delivered            7/24/18 20:41      7/26/18 3:24
# 2    delivered              8/8/18 8:38       8/8/18 8:55
# 3    delivered           11/18/17 19:28    11/18/17 19:45
# 4    delivered            2/13/18 21:18     2/13/18 22:20
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                10/4/17 19:55                10/10/17 21:25
# 1                7/26/18 14:31                  8/7/18 15:27
# 2                 8/8/18 13:50                 8/17/18 18:06
# 3               11/22/17 13:39                  12/2/17 0:28
# 4                2/14/18 19:46                 2/16/18 18:17
#
#   order_estimated_delivery_date  order_item_id  \
# 0                 10/18/17 0:00              1
# 1                  8/13/18 0:00              1
# 2                   9/4/18 0:00              1
# 3                 12/15/17 0:00              1
# 4                  2/26/18 0:00              1
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 2  aa4383b373c6aca5d8797843e5594415  4869f7a5dfa277a7dca6462dcf3b52b2
# 3  d0b61bfb1de832b15ba9d266ca96e5b0  66922902710d126a0e7d26b0e3805106
# 4  65266b2da20d04dbe00c5c2d3bb7859e  2c9e548be18521d1c43cde1c582c6de8
#
#   shipping_limit_date   price  freight_value
# 0       10/6/17 11:07   29.99           8.72
# 1        7/30/18 3:24  118.70          22.76
# 2        8/13/18 8:55  159.90          19.22
# 3      11/23/17 19:45   45.00          27.20
# 4       2/19/18 20:31   19.90           8.72

# %%
olist_sellers_dataset=pd.read_csv('olist_sellers_dataset.csv') #olist seller data set
olist_sellers_dataset.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
olist_seller_order_items=pd.merge(olist_order_order_items, olist_sellers_dataset,on=['seller_id','seller_id']) #full outer join based on seller id
olist_seller_order_items.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  8736140c61ea584cb4250074756d8f3b  ab8844663ae049fda8baf15fc928f47f
# 2  a0151737f2f0c6c0a5fd69d45f66ceea  fc2697314ab7fbeda62bb6f1afa4efcd
# 3  a3bf941183211246f0d42ad757cba127  3718e1873d5dc3e8d96c0ab783278b02
# 4  1462290799412b71be32dd880eaf4e1b  220e4b027f0294fd79d2869ef67e7db6
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered            10/2/17 10:56     10/2/17 11:07
# 1    delivered            8/10/17 13:35     8/10/17 13:50
# 2    delivered            7/12/17 14:11     7/12/17 14:30
# 3    delivered            7/24/17 22:16     7/25/17 22:25
# 4    delivered            8/19/17 14:06      8/22/17 4:10
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                10/4/17 19:55                10/10/17 21:25
# 1                8/11/17 13:52                 8/16/17 19:03
# 2                7/13/17 12:47                 7/18/17 16:24
# 3                7/26/17 14:57                 7/28/17 19:06
# 4                8/23/17 13:54                 8/29/17 19:35
#
#   order_estimated_delivery_date  order_item_id  \
# 0                 10/18/17 0:00              1
# 1                  8/23/17 0:00              1
# 2                  7/25/17 0:00              1
# 3                   8/4/17 0:00              1
# 4                  9/15/17 0:00              1
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1  b00a32a0b42fd65efb58a5822009f629  3504c0cb71d7fa48d967e0e4c94d59d9
# 2  725cbfcaff95a4d43742fdf13cf43c75  3504c0cb71d7fa48d967e0e4c94d59d9
# 3  725cbfcaff95a4d43742fdf13cf43c75  3504c0cb71d7fa48d967e0e4c94d59d9
# 4  d7faab3fa0091d1220a8ada9cae1bab3  3504c0cb71d7fa48d967e0e4c94d59d9
#
#   shipping_limit_date  price  freight_value  seller_zip_code_prefix  \
# 0       10/6/17 11:07  29.99           8.72                    9350
# 1       8/16/17 13:50  75.90           7.79                    9350
# 2       7/18/17 14:30  44.99           7.78                    9350
# 3       7/31/17 22:25  44.99           7.78                    9350
# 4        8/28/17 4:10  29.90          14.10                    9350
#
#   seller_city seller_state
# 0        maua           SP
# 1        maua           SP
# 2        maua           SP
# 3        maua           SP
# 4        maua           SP

# %%
olist_products_dataset=pd.read_csv('olist_products_dataset.csv') #product dataset
olist_products_dataset.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
product_category_name_translation=pd.read_csv('product_category_name_translation.csv') #translation of product dataset
product_category_name_translation.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
prod_cat_trans=pd.merge(olist_products_dataset, product_category_name_translation,on=['product_category_name','product_category_name'])
prod_cat_trans=prod_cat_trans.drop(columns=['product_category_name']) #join product and translation datset, drop repeating column
prod_cat_trans.head()
# Out:
#                          product_id  product_name_lenght  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5                 40.0
# 1  6a2fb4dd53d2cdb88e0432f1284a004c                 39.0
# 2  0d009643171aee696f4733340bc2fdd0                 52.0
# 3  b1eae565a61935e0011ee7682fef9dc9                 49.0
# 4  8da90b37f0fb171b4877c124f965b1f6                 56.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       287.0                 1.0             225.0
# 1                       346.0                 2.0             400.0
# 2                       150.0                 1.0             422.0
# 3                       460.0                 2.0             267.0
# 4                       733.0                 3.0             377.0
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0               16.0               10.0              14.0
# 1               27.0                5.0              20.0
# 2               21.0               16.0              18.0
# 3               17.0               13.0              17.0
# 4               18.0               13.0              15.0
#
#   product_category_name_english
# 0                     perfumery
# 1                     perfumery
# 2                     perfumery
# 3                     perfumery
# 4                     perfumery

# %%
olist_seller_order_product= pd.merge(olist_seller_order_items, prod_cat_trans,on=['product_id','product_id'])
olist_seller_order_product.head()   #joined sellers with their products
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 2  0e7e841ddf8f8f2de2bad69267ecfbcf  26c7ac168e1433912a51b924fbd34d34
# 3  bfc39df4f36c3693ff3b63fcbea9e90a  53904ddbea91e1e92b2b3f1d09a7af86
# 4  8736140c61ea584cb4250074756d8f3b  ab8844663ae049fda8baf15fc928f47f
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered            10/2/17 10:56     10/2/17 11:07
# 1    delivered            8/15/17 18:29     8/15/17 20:05
# 2    delivered             8/2/17 18:24      8/2/17 18:43
# 3    delivered           10/23/17 23:26     10/25/17 2:14
# 4    delivered            8/10/17 13:35     8/10/17 13:50
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                10/4/17 19:55                10/10/17 21:25
# 1                8/17/17 15:28                 8/18/17 14:44
# 2                 8/4/17 17:35                  8/7/17 18:30
# 3               10/27/17 16:48                 11/7/17 18:04
# 4                8/11/17 13:52                 8/16/17 19:03
#
#   order_estimated_delivery_date  order_item_id  \
# 0                 10/18/17 0:00              1
# 1                  8/28/17 0:00              1
# 2                  8/15/17 0:00              1
# 3                 11/13/17 0:00              1
# 4                  8/23/17 0:00              1
#
#                          product_id              ...                \
# 0  87285b34884572647811a353c7ac498a              ...
# 1  87285b34884572647811a353c7ac498a              ...
# 2  87285b34884572647811a353c7ac498a              ...
# 3  87285b34884572647811a353c7ac498a              ...
# 4  b00a32a0b42fd65efb58a5822009f629              ...
#
#   seller_city seller_state  product_name_lenght  product_description_lenght  \
# 0        maua           SP                 40.0                       268.0
# 1        maua           SP                 40.0                       268.0
# 2        maua           SP                 40.0                       268.0
# 3        maua           SP                 40.0                       268.0
# 4        maua           SP                 58.0                       398.0
#
#    product_photos_qty product_weight_g product_length_cm  product_height_cm  \
# 0                 4.0            500.0              19.0                8.0
# 1                 4.0            500.0              19.0                8.0
# 2                 4.0            500.0              19.0                8.0
# 3                 4.0            500.0              19.0                8.0
# 4                 3.0            238.0              20.0               10.0
#
#    product_width_cm  product_category_name_english
# 0              13.0                     housewares
# 1              13.0                     housewares
# 2              13.0                     housewares
# 3              13.0                     housewares
# 4              15.0                           baby
#
# [5 rows x 25 columns]

# %%
#null_columns=olist_seller_order_product.columns[olist_seller_order_product.isnull().any()]
#olist_seller_order_product[null_columns].isnull().sum()
#print(olist_seller_order_product[olist_seller_order_product.isnull().any(axis=1)][null_columns].head())

# %%
order_location_dataset=pd.read_csv('olist_geolocation_dataset.csv')  # Olist location datasest
order_location_dataset.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
order_customer_dataset=pd.read_csv('olist_customers_dataset.csv')  # Olist customer datasest
order_customer_dataset.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
olist_seller_order_customer=pd.merge(olist_seller_order_product, order_customer_dataset,on=['customer_id','customer_id'])
olist_seller_order_customer.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 2  0e7e841ddf8f8f2de2bad69267ecfbcf  26c7ac168e1433912a51b924fbd34d34
# 3  bfc39df4f36c3693ff3b63fcbea9e90a  53904ddbea91e1e92b2b3f1d09a7af86
# 4  8736140c61ea584cb4250074756d8f3b  ab8844663ae049fda8baf15fc928f47f
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered            10/2/17 10:56     10/2/17 11:07
# 1    delivered            8/15/17 18:29     8/15/17 20:05
# 2    delivered             8/2/17 18:24      8/2/17 18:43
# 3    delivered           10/23/17 23:26     10/25/17 2:14
# 4    delivered            8/10/17 13:35     8/10/17 13:50
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                10/4/17 19:55                10/10/17 21:25
# 1                8/17/17 15:28                 8/18/17 14:44
# 2                 8/4/17 17:35                  8/7/17 18:30
# 3               10/27/17 16:48                 11/7/17 18:04
# 4                8/11/17 13:52                 8/16/17 19:03
#
#   order_estimated_delivery_date  order_item_id  \
# 0                 10/18/17 0:00              1
# 1                  8/28/17 0:00              1
# 2                  8/15/17 0:00              1
# 3                 11/13/17 0:00              1
# 4                  8/23/17 0:00              1
#
#                          product_id       ...       product_photos_qty  \
# 0  87285b34884572647811a353c7ac498a       ...                      4.0
# 1  87285b34884572647811a353c7ac498a       ...                      4.0
# 2  87285b34884572647811a353c7ac498a       ...                      4.0
# 3  87285b34884572647811a353c7ac498a       ...                      4.0
# 4  b00a32a0b42fd65efb58a5822009f629       ...                      3.0
#
#   product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0            500.0               19.0                8.0              13.0
# 1            500.0               19.0                8.0              13.0
# 2            500.0               19.0                8.0              13.0
# 3            500.0               19.0                8.0              13.0
# 4            238.0               20.0               10.0              15.0
#
#   product_category_name_english                customer_unique_id  \
# 0                    housewares  7c396fd4830fd04220f754e42b4e5bff
# 1                    housewares  3a51803cc0d012c3b5dc8b7528cb05f7
# 2                    housewares  ef0996a1a279c26e7ecbd737be23d235
# 3                    housewares  e781fdcc107d13d865fc7698711cc572
# 4                          baby  02c9e0c05a817d4562ec0e8c90f29dba
#
#    customer_zip_code_prefix    customer_city  customer_state
# 0                      3149        sao paulo              SP
# 1                      3366        sao paulo              SP
# 2                      2290        sao paulo              SP
# 3                     88032    florianopolis              SC
# 4                      8577  itaquaquecetuba              SP
#
# [5 rows x 29 columns]

# %%
olist_seller_order_customer.to_csv('seller_prdo.csv', sep=',')

# %%
list(olist_seller_order_customer.columns.values)
# Out:
# ['order_id',
#  'customer_id',
#  'order_status',
#  'order_purchase_timestamp',
#  'order_approved_at',
#  'order_delivered_carrier_date',
#  'order_delivered_customer_date',
#  'order_estimated_delivery_date',
#  'order_item_id',
#  'product_id',
#  'seller_id',
#  'shipping_limit_date',
#  'price',
#  'freight_value',
#  'seller_zip_code_prefix',
#  'seller_city',
#  'seller_state',
#  'product_name_lenght',
#  'product_description_lenght',
#  'product_photos_qty',
#  'product_weight_g',
#  'product_length_cm',
#  'product_height_cm',
#  'product_width_cm',
#  'product_category_name_english',
#  'customer_unique_id',
#  'customer_zip_code_prefix',
#  'customer_city',
#  'customer_state']

# %%
olist_seller_order_customer.shape
# Out:
# (111023, 29)

# %%
null_columns=olist_seller_order_customer.columns[olist_seller_order_customer.isnull().any()]
print(null_columns)
olist_seller_order_product[null_columns].isnull().sum()
# Out:
# Index(['order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')
# order_approved_at                  14
# order_delivered_carrier_date     1155
# order_delivered_customer_date    2386
# product_weight_g                    1
# product_length_cm                   1
# product_height_cm                   1
# product_width_cm                    1
# dtype: int64
